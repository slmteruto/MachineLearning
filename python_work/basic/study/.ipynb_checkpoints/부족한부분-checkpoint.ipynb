# %% [markdown]
# ## 부족한 부분
#
#     - 01자료형
#         - count(), find(), index(), join(), split(), strip(),
#         - 바꾸기  replace(), maketrans(), translate()
#         - 얕은 복사, 깊은 복사
#         - 리스트만들기 형식
#         - 리스트 insert(). append(), extend()
#         - tuple 수정
#         - dict 출력 방식
#         - set 함수 (union, intersection?), 추가, 삭제
#
#     - 02 제어문
#         - ASCII 코드 변환
#         - random
#
#     - 03함수
#         - 다른언어에선 리턴이 하나밖에 안됨
#         - 동시 교환이 가능하다. 객체의 주소를 담아서 사용하기 때문
#         - 순서 상관없이 매개변수 주는 법
#         - 가변인수
#         - all(), any()
#         - enumerate(iterator), eval(expression)
#         - map(function, iterable)
#         - zip(iterable)
#         - import math
#         - import datetime
#         - import sys  /  명령행 인자 sys.argv[0]
#         - import os
#         - 파일처리 함수(내장)
#         - import glob
#         - 재귀함수
#
#     - 04 클래스
#         - 데코레이터 staticmethod, classmethod
#         - 임시변수
#         - List Comprehension
#         - w.upper(), w.lower(), len(w)
#         - 자식이 부모한테 접근하는 방법    super
#         - __변수  -> getter 메소드, setter 메소드
#         - classmethod, staticmethod 상속일 시
#         - 파이썬은 인터페이스랑 클래스를 구별하지 않는다,무조건 클래스 개념
#         - 다중상속
#         - 추상클래스, 추상메소드, import abc
#         - 클래스 최상위 부모 Object 의 함수들
#
#     - 05 고급함수
#         - nonlocal
#         - closer (클로저)
#         - print((lambda x, y : x + y)(2,4))
#         - 함수감싸기 hi = make2(make1(hello))
#
#     - 06 모듈과 패키지
#         - 선언방법
#
#     - 07 예외처리, 파일 객체
#         - traceback 역추적기  import traceback
#         - raise 예외처리 발생기
#         - finally, else 차이
#         - 예외처리 클래스 만들기
#         - pickle (객체처리) 직렬화기 import pickle
#
#     - 08 단위테스트
#         - import unittest
#         - assertEqual(sum(1,2),3)
#         - if __name__ == "__main__" :
